# %% [markdown]
# <a href="https://colab.research.google.com/github/mushrafi88/MSE_510/blob/main/Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mushrafi Munim Sushmit

# %%
print("I am familiar with Python")
# Out:
# I am familiar with Python
